# %%
import pandas as pd
import numpy as np
import calendar

def read_csv_data(filepath, rows=None, encoding="unicode_escape"):
    return pd.read_csv(filepath, encoding="utf-8-sig", sep=",", nrows=rows)

def extract_month_data(df, month_year_str):
    """Extract data for a specific month."""
    return df[df["Timestamp"].str.contains(month_year_str)]


def process_pm_data(df):
    """Process PMV Data."""
    # Flatten multi-index columns
    df.columns = ['_'.join(col).strip() for col in df.columns.values]
    
    # Rename the column "ID_Unnamed: 0_level_1" to "ID"
    df = df.rename(columns={"ID_Unnamed: 0_level_1": "ID"})
    
    
    return df



def preprocess_data(pmv_17, pmv_18):
    # Data Transformation: Convert columns to float, fill NaN with mean
    for df in [pmv_17, pmv_18]:
        for col in df.columns:
            df[col] = df[col].astype(str).astype(float)
        df.fillna(df.mean(), inplace=True)
    
    return pmv_17, pmv_18


def combine_monthly_data(bedroom_df, lr_df, pmv_df, month_str):
    x = extract_month_data(bedroom_df, month_str)
    y = extract_month_data(lr_df, month_str)
    
    # Rename columns for clarity
    x.columns = ['bedroom_' + str(col) for col in x.columns]
    y.columns = ['living_room_' + str(col) for col in y.columns]
    
    combined_df = pd.concat([x, y], axis=1).fillna(0) 

    # Drop the Timestamp columns
    combined_df = combined_df.drop(columns=[col for col in combined_df if 'Timestamp' in col])
    
    # Check each column in the combined_df
    for col in combined_df.columns:
        # Check if all values in the column are zero
        if (combined_df[col] == 0).all():
            combined_df.drop(columns=[col], inplace=True)
        else:
            # Replace zeros with the mean of the column
            col_mean = combined_df[col][combined_df[col] != 0].mean()
            combined_df[col] = combined_df[col].replace(0, col_mean)

    # Save the modified combined_df
    combined_df.to_csv(month_str.replace("/", "_") + ".csv", index=False, encoding='utf-8-sig')
    # Get the TSV column name for the given month/year
    month_name = month_str.split("/")[0]
    year_suffix = month_str.split("/")[1][-2:]
    month_name_dict = {
        "11": "November",
        "12": "December",
        "01": "January",
        "02": "February",
        "03": "March"
    }
    month_col_name = month_name_dict[month_name]+"_" + year_suffix + "_TSV"
    
    # Create a dictionary to hold the TSV values for each ID for the given month/year
    tsv_values = pmv_df.set_index('ID')[month_col_name].to_dict()

    # Create a new row filled with NaN, except for the ID columns which will hold the TSV values
    new_row = {col: np.nan for col in combined_df.columns}
    for col in combined_df.columns:
        if "bedroom_ID" in col or "living_room_ID" in col:
            id_str = col.split('ID')[-1]
            id_num = int(id_str)
            new_row[col] = tsv_values.get(id_num, np.nan)
    
    combined_df = pd.concat([combined_df, pd.DataFrame([new_row])], ignore_index=True)
    
    # Save the modified combined_df
    combined_df.to_csv(month_str.replace("/", "_") + ".csv", index=False, encoding='utf-8-sig')

# Rest of the main function...

def main():
    # Load Data
    bedroom_df = read_csv_data("Winter_thermal_comfort_dataset/Bedroom_data.csv", 4007).drop("ID27", axis=1)
    lr_df = read_csv_data("Winter_thermal_comfort_dataset/living_room_data.csv", 4007, encoding="utf-8-sig").dropna(subset=["Timestamp"])
    # Process PMV Data
    pmv_17 = process_pm_data(pd.read_excel('Winter_thermal_comfort_dataset/PMV_TSV.xlsx', sheet_name='2016 17', header=[0,1]))
    pmv_18 = process_pm_data(pd.read_excel('Winter_thermal_comfort_dataset/PMV_TSV.xlsx', sheet_name='2017 18',  header=[0,1]))
    # Rename Columns for clarity in pmv data
    pmv_17, pmv_18 = preprocess_data(pmv_17, pmv_18)
    print(pmv_17)
    pmv_df = pmv_17.merge(pmv_18, on='ID', how='outer')

    print(pmv_df)
    # Extract data for each month
    months = ["11/2016", "12/2016", "01/2017", "02/2017", "03/2017", "12/2017", "01/2018", "02/2018", "03/2018"]

    for month in months:
        combine_monthly_data(bedroom_df, lr_df, pmv_df, month)

if __name__ == "__main__":
    main()
# Out:
#       ID  November_16_PMV  November_16_TSV  December_16_PMV  December_16_TSV  \
# 0    1.0           -3.388              3.0           -3.183              1.0
# 1    2.0           -1.524             -1.0           -1.088              1.0
# 2    4.0           -1.240              0.0           -1.188              0.0
# 3    5.0           -1.864             -1.0           -1.519              1.0
# 4    9.0           -1.385              0.0           -1.502              0.0
# 5   11.0           -2.812             -1.0           -2.640             -2.0
# 6   12.0           -0.177              1.0           -0.242             -2.0
# 7   14.0           -1.138              1.0           -1.470              1.0
# 8   15.0           -1.068              1.0           -0.898              1.0
# 9   16.0           -0.394              1.0           -0.400              1.0
# 10  19.0           -0.568              1.0           -0.639              1.0
# 11  21.0           -1.170              1.0           -1.533              1.0
# 12  22.0           -0.825              1.0           -0.186              1.0
# 13  23.0           -0.375              1.0           -0.535              1.0
# 14  24.0           -1.490              1.0           -2.127              1.0
# 15  25.0           -0.119             -1.0           -0.336              1.0
# 16  26.0           -1.976              1.0           -2.037              1.0
# 17  27.0           -0.604              0.0           -0.840              1.0
# 18  28.0           -0.906              0.0           -0.850              0.0
# 19  29.0           -0.330              1.0           -0.834              1.0
# 20  31.0           -3.060             -1.0           -3.740              1.0
# 21  32.0           -2.340              1.0           -1.877              1.0
# 22  33.0           -1.668              2.0           -1.092             -2.0
# 23  34.0           -2.040             -2.0           -2.224             -2.0
# 24  35.0           -0.219             -2.0           -0.460              0.0
# 25  36.0           -0.464              1.0           -0.326              1.0
# 26  38.0           -1.420              0.0           -1.459             -1.0
# 27  39.0           -1.962              1.0           -1.548              1.0
# 28  40.0           -1.415             -1.0           -1.714             -1.0
# 29  41.0           -0.022              1.0           -0.529              1.0
# 30  43.0           -1.922              1.0           -1.760              1.0
#
#     January_17_PMV  January_17_TSV  February_17_PMV  February_17_TSV  \
# 0           -3.647             0.0           -3.894              1.0
# 1           -0.908             1.0           -1.285             -1.0
# 2           -1.962            -2.0           -1.207              0.0
# 3           -1.401             1.0           -1.719              0.0
# 4           -2.060            -1.0           -2.150             -1.0
# 5           -3.018            -3.0           -3.560             -3.0
# 6           -0.235             0.0            0.000             -2.0
# 7           -1.341             1.0           -2.070              1.0
# 8           -1.236             2.0           -0.504              1.0
# 9           -1.160             1.0           -0.714             -1.0
# 10          -0.763             1.0           -0.660              1.0
# 11          -1.524             1.0           -1.830              1.0
# 12          -0.230             1.0           -1.220              1.0
# 13          -0.402             1.0           -0.550             -2.0
# 14          -1.585             1.0           -2.000              1.0
# 15          -0.379             1.0           -0.189             -2.0
# 29  41.0           -0.022              1.0           -0.529              1.0
# 30  43.0           -1.922              1.0           -1.760              1.0
# 31   8.0              NaN              NaN              NaN              NaN
# 32  10.0              NaN              NaN              NaN              NaN
# 33  20.0              NaN              NaN              NaN              NaN
#
#     January_17_PMV  January_17_TSV  February_17_PMV  February_17_TSV  \
# 0           -3.647             0.0           -3.894              1.0
# 1           -0.908             1.0           -1.285             -1.0
# 2           -1.962            -2.0           -1.207              0.0
# 3           -1.401             1.0           -1.719              0.0
# 4           -2.060            -1.0           -2.150             -1.0
# 5           -3.018            -3.0           -3.560             -3.0
# 6           -0.235             0.0            0.000             -2.0
# 7           -1.341             1.0           -2.070              1.0
# 8           -1.236             2.0           -0.504              1.0
# 9           -1.160             1.0           -0.714             -1.0
# 10          -0.763             1.0           -0.660              1.0
# 11          -1.524             1.0           -1.830              1.0
# 12          -0.230             1.0           -1.220              1.0
# 13          -0.402             1.0           -0.550             -2.0
# 14          -1.585             1.0           -2.000              1.0
# 15          -0.379             1.0           -0.189             -2.0
# 16          -1.912             1.0            2.030              1.0
# 17          -0.860             0.0           -0.971              0.0
# 18          -1.224            -2.0           -0.520              0.0
# 19          -1.070             1.0           -0.354              1.0
# 20          -4.250            -2.0           -3.690             -2.0
# 21          -2.254             1.0           -2.290              1.0
# 22          -1.721            -3.0           -2.197             -3.0
# 23          -3.190            -3.0           -2.540             -3.0
# 24          -1.111            -3.0           -0.890             -2.0
# 25          -0.556             1.0           -0.196              1.0
# 26          -1.176             0.0           -1.399              0.0
# 27          -2.390             1.0           -1.610              1.0
# 28          -1.915            -2.0           -1.769             -1.0
# 29          -0.466             1.0           -0.283              1.0
# 30          -2.498             1.0           -1.397              1.0
# 31             NaN             NaN              NaN              NaN
# 32             NaN             NaN              NaN              NaN
# 33             NaN             NaN              NaN              NaN
#
#     March_17_PMV  March_17_TSV  December_17_PMV  December_17_TSV  \
# 0         -3.275           1.0            -2.90              0.0
# 1         -2.347          -1.0            -3.50              1.0
# 2         -1.050           0.0            -1.90             -1.0
# 3         -1.912          -1.0            -2.23             -1.0
# 4         -2.150          -1.0            -1.00              1.0
# 5         -2.840          -2.0            -3.10             -2.0
# 6         -0.040           0.0              NaN              NaN
# 7         -1.177           1.0              NaN              NaN
# 8         -1.190           1.0            -2.29              0.0
# 9         -0.396           1.0              NaN              NaN
# 10        -0.749           1.0            -0.50              1.0
# 11        -1.522           1.0            -1.50              1.0
# 12        -1.512           1.0             0.01              1.0
# 13        -0.687           1.0              NaN              NaN
# 14        -1.810           1.0            -3.17              0.0
# 15        -0.347           1.0            -0.60              1.0
# 16        -1.763           1.0              NaN              NaN
# 17        -1.020           0.0              NaN              NaN
# 18        -0.520           0.0            -0.99             -1.0
# 19        -1.179           1.0            -0.33              1.0
# 20        -3.810          -2.0            -1.40              0.0
# 21        -2.710           1.0            -1.90              0.0
# 22        -1.397          -3.0              NaN              NaN
# 23        -2.263          -2.0            -1.60             -2.0
# 24        -0.950          -2.0            -0.18              0.0
# 25        -0.101           1.0            -0.46             -1.0
# 26        -1.317           0.0            -1.40              0.0
# 27        -1.963           1.0            -1.08              1.0
# 28        -2.082          -1.0            -1.53             -1.0
# 29        -0.550           1.0              NaN              NaN
# 30        -2.040           1.0            -2.50              1.0
# 31           NaN           NaN            -1.40              1.0
# 32           NaN           NaN            -1.30             -1.0
# 33           NaN           NaN            -1.20              1.0
#
#     January_18_PMV  January_18_TSV  February_18_PMV  February_18_TSV  \
# 0        -1.031429       -0.571429        -3.300000         0.000000
# 1        -0.980000        0.000000        -2.100000         1.000000
# 2        -1.031429       -0.571429        -1.374667        -0.142857
# 3        -1.031429       -0.571429        -1.374667        -0.142857
# 4        -1.620000       -1.000000        -1.710000        -1.000000
# 5        -3.100000       -2.000000        -2.500000        -2.000000
# 6              NaN             NaN              NaN              NaN
# 7              NaN             NaN              NaN              NaN
# 8        -0.500000        1.000000        -0.400000         1.000000
# 9              NaN             NaN              NaN              NaN
# 10        0.830000        1.000000        -1.374667        -0.142857
# 11       -1.031429       -0.571429        -1.374667        -0.142857
# 12       -1.031429       -0.571429        -1.374667        -0.142857
# 13             NaN             NaN              NaN              NaN
# 14       -0.900000       -1.000000        -0.220000         1.000000
# 15       -1.031429       -0.571429        -0.440000        -0.142857
# 16             NaN             NaN              NaN              NaN
# 17             NaN             NaN              NaN              NaN
# 18       -0.600000       -2.000000        -0.500000        -2.000000
# 19       -1.031429       -0.571429        -1.020000         1.000000
# 20       -2.080000        1.000000        -2.150000         1.000000
# 21       -1.031429       -0.571429        -3.600000         1.000000
# 22             NaN             NaN              NaN              NaN
# 23       -1.031429       -0.571429        -1.374667        -0.142857
# 24       -0.620000       -2.000000        -1.374667        -0.142857
# 25       -0.720000       -2.000000         0.110000        -3.000000
# 26       -1.300000       -1.000000        -1.374667        -0.142857
# 27       -1.031429       -0.571429        -1.374667        -0.142857
# 28       -1.031429       -0.571429        -1.374667        -0.142857
# 29             NaN             NaN              NaN              NaN
# 30       -1.031429       -0.571429        -1.374667        -0.142857
# 31       -0.720000        1.000000        -1.250000         1.000000
# 32       -1.200000       -1.000000        -0.650000        -1.000000
# 33       -0.930000        0.000000        -0.890000         0.000000
#
#     March_18_PMV  March_18_TSV
# 0        -3.0000          0.00
# 1        -1.6700          1.00
# 2        -0.7000          0.00
# 3        -1.5000          0.00
# 4        -1.3500         -1.00
# 5        -3.2000         -1.00
# 6            NaN           NaN
# 7            NaN           NaN
# 8        -0.9000         -1.00
# 9            NaN           NaN
# 10       -1.3524         -0.44
# 11       -1.0000          0.00
# 12       -0.1900          1.00
# 13           NaN           NaN
# 14       -1.5000         -2.00
# 15       -1.2400          1.00
# 16           NaN           NaN
# 17           NaN           NaN
# 18       -0.9500          1.00
# 19       -0.8000         -1.00
# 20       -1.7200          1.00
# 21       -2.3000          0.00
# 22           NaN           NaN
# 23       -0.0700          0.00
# 24       -0.8600         -1.00
# 25       -0.7700         -3.00
# 26       -1.8900         -2.00
# 27       -0.2300         -1.00
# 28       -2.1000         -1.00
# 29           NaN           NaN
# 30       -1.9800          1.00
# 31       -1.8000          0.00
# 32       -1.0700         -1.00
# 33       -1.0200         -2.00
